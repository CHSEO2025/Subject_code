# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\MEGHANA\MST2025\ARTEXR.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Rammohan\AppData\Local\Temp\ipykernel_13848\1128667123.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_excel("C:\MEGHANA\MST2025\ARTEXR.xlsx")

# %%
df.head(5)
# Out:
#   DIST  COLL  STREAM  ROLLNO CENTERCODE            NAME            FNAME  \
# 0   AA     1       4       1       AA01   SAMINA KHATUN         SK RAHIM
# 1   AA     1       4       2       AA01  SUSMITA MAHURI  SUSHANTA MAHURI
# 2   AA     1       4       3       AA01      ANANYA DEY   KESHARILAL DEY
# 3   AA     1       4       4       AA01  JUGASMITA JENA       SAPAN JENA
# 4   AA     1       4       5       AA01    SABITA DALAI     GOUTAM DALAI
#
#               MNAME        R_NO SEX  ...  CAN_TAG SCHEME_TAG IN_WORK INCOME  \
# 0       FARIDA BIBI  AA01A22052   F  ...      NaN        NaN       A      0
# 1  GOURIBALA MAHURI  AA01A21091   F  ...      NaN        NaN       A      0
# 2    SNEHASHREE DEY  AA01A20078   F  ...      NaN        NaN       A      0
# 3   MADHUSMITA JENA  AA01A19132   F  ...      NaN        NaN       A      0
# 4     KALPANA DALAI  AA01A18075   F  ...      NaN        NaN       A      0
#
#   INSTANTSUB  MNR_REF_NO  FILLER1  YOGA  BASIC  FILLER3
# ...

# %%
df.columns
# Out:
# Index(['DIST', 'COLL', 'STREAM', 'ROLLNO', 'CENTERCODE', 'NAME', 'FNAME',
#        'MNAME', 'R_NO', 'SEX', 'COM', 'CAT', 'APEARING', 'PREV_NO', 'E_S',
#        'ENGTAG1', 'E1M', 'ENG1HCR', 'ENGTAG2', 'E2M', 'ENG2HCR', 'M_S',
#        'MILTAG', 'MM', 'MILHCR', 'O1', 'OPT1T1TAG', 'O1T1M', 'OPT1T1HCR',
#        'OPT1T2TAG', 'O1T2M', 'OPT1T2HCR', 'OPT1P1TAG', 'O1P1M', 'OPT1P1HCR',
#        'O2', 'OPT2T1TAG', 'O2T1M', 'OPT2T1HCR', 'OPT2T2TAG', 'O2T2M',
#        'OPT2T2HCR', 'OPT2P1TAG', 'O2P1M', 'OPT2P1HCR', 'O3', 'OPT3T1TAG',
#        'O3T1M', 'OPT3T1HCR', 'OPT3T2TAG', 'O3T2M', 'OPT3T2HCR', 'OPT3P1TAG',
#        'O3P1M', 'OPT3P1HCR', 'OPT3P2TAG', 'O3P2M', 'OPT3P2HCR', 'O4',
#        'OPT4T1TAG', 'O4T1M', 'OPT4T1HCR', 'OPT4T2TAG', 'O4T2M', 'OPT4T2HCR',
#        'OPT4P1TAG', 'O4P1M', 'OPT4P1HCR', 'OPT4P2TAG', 'O4P2M', 'OPT4P2HCR',
#        'EXTRA_EXCE', 'AGGR', 'AGGR_WITH', 'RESULT_TAG', 'HARD_TAG', 'ENG_PASS',
#        'MIL_PASS', 'OPT1THPASS', 'OPT1PRPASS', 'OPT2THPASS', 'OPT2PRPASS',
# ...

# %%
import pandas as pd

# Load your Excel file
df = pd.read_excel("C:\MEGHANA\MST2025\VOCREG.xlsx")

# List of relevant subject columns
subject_cols = ['E_S', 'M_S','O1','O2','O3','O4']

# Combine all values from these columns and count occurrences
subject_counts = df[subject_cols].stack().value_counts()

# Show the result
print(subject_counts)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Rammohan\AppData\Local\Temp\ipykernel_6632\3346051759.py:4: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_excel("C:\MEGHANA\MST2025\VOCREG.xlsx")
# E      5049
# O      4765
# PHY    3025
# CHE    3025
# ECO    2024
# M      1720
# BIO    1305
# POL    1266
# HIS    1266
# ITE     990
# BSM     758
# ACT     758
# HOR     537
# EAH     492
# AGD     476
# SPL     438
# OM      375
# TAH     347
# BFI     302
# AVT     208
# CRM     136
# MLT     135
# HV       95
# U        86
# H        85
# INS      81
# OD       55
# IF       54
# S        52
# CP       44
# AE       43
# OV       39
# AGP      39
# TAB      34
# PDF      30
# DRA      27
# SER      20
# T        18
# TD       17
# PAI      14
# AAR      12
# HVI      11
# CRA      10
# GA        7
# CD        6
# MS        6
# SET       5
# OP        4
# FLU       3
# Name: count, dtype: int64

# %%
##  'M_S','O1','O2','O3','O4'

# %%
df['M_S'].value_counts()
# Out:
# M_S
# O     4765
# U       86
# H       85
# S       52
# AE      43
# T       18
# Name: count, dtype: int64

# %%
df['O1'].value_counts()
# Out:
# O1
# PHY    3025
# HIS    1266
# ACT     758
# Name: count, dtype: int64

# %%
df['O2'].value_counts()
# Out:
# O2
# CHE    3025
# POL    1266
# BSM     758
# Name: count, dtype: int64

# %%
df['O3'].value_counts()
# Out:
# O3
# ECO    2024
# M      1720
# BIO    1305
# Name: count, dtype: int64

# %%
df['O4'].value_counts()
# Out:
# O4
# ITE    990
# HOR    537
# EAH    492
# AGD    476
# SPL    438
# OM     375
# TAH    347
# BFI    302
# AVT    208
# CRM    136
# MLT    135
# HV      95
# INS     81
# OD      55
# IF      54
# CP      44
# AGP     39
# OV      39
# TAB     34
# PDF     30
# DRA     27
# SER     20
# TD      17
# PAI     14
# AAR     12
# HVI     11
# CRA     10
# GA       7
# MS       6
# CD       6
# SET      5
# OP       4
# FLU      3
# Name: count, dtype: int64
